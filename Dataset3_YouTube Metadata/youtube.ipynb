# %% [markdown]
# # `Dataset #3: YouTube Metadata Features`

# %%
import pandas as pd
import datetime
import json

# %% [markdown]
# Opening the raw YouTube Tending Videos metadata dataset and stroing its data in a dataframe.
#
# https://www.kaggle.com/datasets/rsrishav/youtube-trending-video-dataset?select=US_youtube_trending_data.csv

# %%
# Read in raw YouTube Trending Videos metadata
youtube_raw_df = pd.read_csv('raw_youtube_metadata/US_youtube_trending_data.csv', header=0)

# typecast columns to datetime object
youtube_raw_df['trending_date'] = pd.to_datetime(youtube_raw_df['trending_date'])
youtube_raw_df['publishedAt'] = pd.to_datetime(youtube_raw_df['publishedAt'])

# %%
# Remove all unused columns from df
youtube_raw_df.drop('thumbnail_link', axis=1, inplace=True)
youtube_raw_df.drop('comments_disabled', axis=1, inplace=True)
youtube_raw_df.drop('ratings_disabled', axis=1, inplace=True)
youtube_raw_df.drop('description', axis=1, inplace=True)

youtube_raw_df = youtube_raw_df.sort_values(by='trending_date', ascending=True)

# %%
youtube_raw_df
# Out:
#            video_id                                              title  \
# 0       3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 127     6f-jjV5LJoE    Road Rage – Why Motorcycle Riders Smash Windows
# 128     QsUfsZzxi9c                  Whatever You Build, I'll Pay For!
# 129     THQH9QJKrIE  Trump signs executive orders on unemployment, ...
# 130     xCkpA4_H1x4  UPDATE: CLAN WARS 2 ⚔️ How does it work? TV Ro...
# ...             ...                                                ...
# 187859  nZiJQuao8v0  Israel Adesanya's Fight Breakdown & Picks | UF...
# 187860  jQ58UEXrFzs   1.20 NAME REVEAL and more... | MINECRAFT MONTHLY
# 187861  SRPjb9UbaRM  Rauw Alejandro - QUE RICO CH**NGAMOS (Official...
# 187851  uRL4l2GOqXk      Randy Discovers Japanese Toilets - SOUTH PARK
# 187989  zMpprTBefdg  Can You Beat Pokémon Scarlet Using ONLY DRAGON...
#
#                      publishedAt                 channelId  \
# 0      2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg
# 127    2020-08-09 15:00:01+00:00  UCNSMdQtn1SuFzCZjfK2C7dQ
# 128    2020-08-06 17:00:23+00:00  UCIPPMRA040LQr5QPyJEbmXA
# 129    2020-08-08 21:15:00+00:00  UCHd62-u_v4DvJ8TCFtpi4GA
# 130    2020-08-08 14:30:05+00:00  UC_F8DoJf9MZogEOU51TpTbQ
# ...                          ...                       ...
# 187859 2023-03-02 16:00:24+00:00  UC1oigGPZ4A6atKCnj17ow8Q
# 187860 2023-03-02 16:00:25+00:00  UC1sELGmy5jp5fQUugmuYlXQ
# 187861 2023-03-02 20:00:08+00:00  UC_Av98lDjf5KvFib5elhpYg
# 187851 2023-03-02 16:46:05+00:00  UC7R27sAWc_DqOldtI1JcYhQ
# 187989 2023-02-26 20:00:15+00:00  UCl4vHlsw4s5TVGFpVsj54Rg
#
#               channelTitle  categoryId             trending_date  \
# 0                 Brawadis          22 2020-08-12 00:00:00+00:00
# 127               FortNine           2 2020-08-12 00:00:00+00:00
# 128         MrBeast Gaming          20 2020-08-12 00:00:00+00:00
# 129        Washington Post          25 2020-08-12 00:00:00+00:00
# 130           Clash Royale          20 2020-08-12 00:00:00+00:00
# ...                    ...         ...                       ...
# 187859     FREESTYLEBENDER          17 2023-03-05 00:00:00+00:00
# 187860           Minecraft          20 2023-03-05 00:00:00+00:00
# 187861      Rauw Alejandro          10 2023-03-05 00:00:00+00:00
# 187851  South Park Studios          23 2023-03-05 00:00:00+00:00
# 187989            Keegan J          20 2023-03-05 00:00:00+00:00
#
#                                                      tags  view_count  \
# 0       brawadis|prank|basketball|skits|ghost|funny vi...     1514614
# 127     motorcycle road rage compilation|motorcycle cr...      342870
# 128                                                [None]    13073796
# 129     debt|student loans|unemployment aid|cares act|...      523172
# 130     Clash Royale|Clash Royale Game|Supercell|Super...     2635254
# ...                                                   ...         ...
# 187859  jon jones|ufc 285|jon jones vs ciryl gane|ciry...      521624
# 187860  Minecraft|Update 1.20|Sniffer|Cherry Blossom|L...     1176337
# 187861  rauw alejandro|rauw|rauw alejandro 2020|rauw a...     1551113
# 187851  south park (tv program)|south park|South Park ...     1304979
# 187989          Pokemon|Challenge|Scarlet|Violet|Monotype      630022
#
#           likes  dislikes  comment_count
# 0        156908      5855          35313
# 127       30254       580           3124
# 128     1643982     16286          97749
# 129        6045      1076           5109
# 130       73921      2694           3447
# ...         ...       ...            ...
# 187859    18032         0           1466
# 187860   102674         0           6324
# 187861    46499         0           1275
# 187851    28356         0           2490
# 187989    14052         0           1834
#
# [187990 rows x 12 columns]

# %%
# Removing all duplicate dates and sorting the dates
trending_dates = list(set(youtube_raw_df["trending_date"]))
trending_dates = sorted(trending_dates, key=lambda x: x.date())

# Converting and storing data in a dictionary
trending_dates_dict = {k: None for k in trending_dates}

# %%
# iterate over the rows of the dataframe to only get the greatest trending video for the day base on the numbe rof views it has and storing it in our dictionary.
for index, row in youtube_raw_df.iterrows():
    if trending_dates_dict.get(row["trending_date"]) is None:
        trending_dates_dict[row["trending_date"]] = row
    else:
        if trending_dates_dict.get(row["trending_date"])['view_count'] < row["view_count"]:
            trending_dates_dict[row["trending_date"]] = row

# %%
# Convert dictionary values to list
trending_dates_lsit = list(trending_dates_dict.values())

# Convert list to DataFrame
youtube_df = pd.DataFrame(trending_dates_lsit)

# %%
list_cat = list(set(youtube_df['categoryId']))

# %% [markdown]
# # Getting dictionary of Categories

# %%
# Read in JSON file the indicate which catergories are associated with which IDs
with open('raw_youtube_metadata/US_category_id.json', 'r') as f:
    data = json.load(f)

# %%
# Storing the categrories and catgeory IDs in a dictionary
categories_dict = {}

for item in data.get('items'):
    id = item.get('id')
    category = item.get('snippet').get('title')
    categories_dict[id] = category

# %% [markdown]
# # Convert youtube_df categoryId column to category names

# %%
for index, row in youtube_df.iterrows():
    id = row['categoryId']
    category = categories_dict.get(str(id))
    youtube_df.at[index, 'categoryId'] = category

# %%
youtube_df['trending_date'] = pd.to_datetime(youtube_df['trending_date'])

# %%
youtube_df
# Out:
#            video_id                                              title  \
# 51      hsm4poTWjMs  Cardi B - WAP feat. Megan Thee Stallion [Offic...
# 280     hsm4poTWjMs  Cardi B - WAP feat. Megan Thee Stallion [Offic...
# 508     hsm4poTWjMs  Cardi B - WAP feat. Megan Thee Stallion [Offic...
# 733     hsm4poTWjMs  Cardi B - WAP feat. Megan Thee Stallion [Offic...
# 985     hsm4poTWjMs  Cardi B - WAP feat. Megan Thee Stallion [Offic...
# ...             ...                                                ...
# 187059  jZGpkLElSu8            KAROL G, Shakira - TQG (Official Video)
# 187288  jZGpkLElSu8            KAROL G, Shakira - TQG (Official Video)
# 187526  jZGpkLElSu8            KAROL G, Shakira - TQG (Official Video)
# 187747  jZGpkLElSu8            KAROL G, Shakira - TQG (Official Video)
# 187947  HjBo--1n8lI  Rihanna’s FULL Apple Music Super Bowl LVII Hal...
#
#                      publishedAt                 channelId channelTitle  \
# 51     2020-08-07 04:00:10+00:00  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B
# 280    2020-08-07 04:00:10+00:00  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B
# 508    2020-08-07 04:00:10+00:00  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B
# 733    2020-08-07 04:00:10+00:00  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B
# 985    2020-08-07 04:00:10+00:00  UCxMAbVFmxKUVGAll0WVGpFw      Cardi B
# ...                          ...                       ...          ...
# 187059 2023-02-24 05:00:09+00:00  UCz9yS18zJGQObwUL_K-ICnw   KarolGVEVO
# 187288 2023-02-24 05:00:09+00:00  UCz9yS18zJGQObwUL_K-ICnw   KarolGVEVO
# 187526 2023-02-24 05:00:09+00:00  UCz9yS18zJGQObwUL_K-ICnw   KarolGVEVO
# 187747 2023-02-24 05:00:09+00:00  UCz9yS18zJGQObwUL_K-ICnw   KarolGVEVO
# 187947 2023-02-13 03:58:18+00:00  UCDVYQ4Zhbm3S2dlz7P1GBDg          NFL
#
#        categoryId             trending_date  \
# 51          Music 2020-08-12 00:00:00+00:00
# 280         Music 2020-08-13 00:00:00+00:00
# 508         Music 2020-08-14 00:00:00+00:00
# 733         Music 2020-08-15 00:00:00+00:00
# 985         Music 2020-08-16 00:00:00+00:00
# ...           ...                       ...
# 187059      Music 2023-03-01 00:00:00+00:00
# 187288      Music 2023-03-02 00:00:00+00:00
# 187526      Music 2023-03-03 00:00:00+00:00
# 187747      Music 2023-03-04 00:00:00+00:00
# 187947     Sports 2023-03-05 00:00:00+00:00
#
#                                                      tags  view_count  \
# 51      Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...    76805026
# 280     Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...    82764000
# 508     Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...    88240316
# 733     Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...    93935173
# 985     Cardi B|Cardi|Atlantic Records|rap|hip hop|tra...    98442414
# ...                                                   ...         ...
# 187059  karol|tqg|tqg karol|tqg shakira|karol shakira|...   110562954
# 187288  karol|tqg|tqg karol|tqg shakira|karol shakira|...   120081662
# 187526  karol|tqg|tqg karol|tqg shakira|karol shakira|...   129191084
# 187747  karol|tqg|tqg karol|tqg shakira|karol shakira|...   138548083
# 187947        NFL|Football|American Football|sport|sports    96107476
#
#           likes  dislikes  comment_count
# 51      2820345    382578         270263
# 280     2932434    408060         282770
# 508     3032720    432629         293887
# 733     3131947    452822         303479
# 985     3207729    467717         310630
# ...         ...       ...            ...
# 187059  5108686         0         189867
# 187288  5233866         0         193373
# 187526  5347462         0         196401
# 187747  5461423         0         199368
# 187947  2575964         0         146821
#
# [919 rows x 12 columns]

# %% [markdown]
# # Combining Youtube Dataset with Master Pixstory Dataset

# %% [markdown]
# `Features`
# 1. `Title of Daily Trending Youtube Video (video_id)`
# 2. `Channel Title of Daily Trending Youtube Video (channelId)`
# 3. `Category Type (categoryId)`
# 4. `View Count`
# 5. `Likes Count`
# 6. Dislikes Count
# 7. Comments Count
# 8. Likes-to-Dislikes Ratio
# 9. Views-to_Likes Ratio

# %%
df_master_dataset = pd.read_csv("../Master Datasets/Master_Dataset_Raw.csv")

youtube_df['trending_date'] = pd.to_datetime(youtube_df['trending_date'])
youtube_df['trending_date'] = pd.to_datetime(youtube_df['trending_date'].dt.date)

youtube_df['trending_date'] = youtube_df['trending_date'].astype(str)
df_master_dataset['Account Created Date'] = df_master_dataset['Account Created Date'].astype(str)

# %%
# Looping through each row in the Pixstory datasets, and adding the YouTube Trending Video Metadata

youtube_vid_filler = ["I'm Coming Out", "NikkeTutorials", "Fashion", 36400000, 3000000]

for index, row in df_master_dataset.iterrows():

    youtube_vid = youtube_df[youtube_df['trending_date'] == row['Date (No Timestamp)']]
    youtube_vid = youtube_vid.values.tolist()

    if len(youtube_vid) > 0:
        youtube_vid_filler = youtube_vid

    try:
        df_master_dataset.loc[index, 'YouTube Trending Video Title'] = youtube_vid[0][1]
        df_master_dataset.loc[index, 'YouTube Trending Video Channel'] = youtube_vid[0][4]
        df_master_dataset.loc[index, 'YouTube Trending Video Category'] = youtube_vid[0][5]
        df_master_dataset.loc[index, 'YouTube Trending Video Views'] = youtube_vid[0][8]
        df_master_dataset.loc[index, 'YouTube Trending Video Likes'] = youtube_vid[0][9]

    except:
        df_master_dataset.loc[index, 'YouTube Trending Video Title'] = youtube_vid_filler[0]
        df_master_dataset.loc[index, 'YouTube Trending Video Channel'] = youtube_vid_filler[1]
        df_master_dataset.loc[index, 'YouTube Trending Video Category'] = youtube_vid_filler[2]
        df_master_dataset.loc[index, 'YouTube Trending Video Views'] = youtube_vid_filler[3]
        df_master_dataset.loc[index, 'YouTube Trending Video Likes'] = youtube_vid_filler[4]

    finally:
        continue

# %%
# Few dates were missing from the Youtube Metadata Dataset, so we are manualy enetering the highest trending video metadata for these dates

# topTrendingVideoManual_1 = ["I'm Coming Out", "NikkeTutorials", "Fashion", 36400000, 3000000]

# for i in range(5):
#     df_master_dataset.at[i, 'YouTube Trending Video Title'] = topTrendingVideoManual_1[0]
#     df_master_dataset.at[i, 'YouTube Trending Video Channel'] = topTrendingVideoManual_1[1]	
#     df_master_dataset.at[i, 'YouTube Trending Video Category'] = topTrendingVideoManual_1[2]
#     df_master_dataset.at[i, 'YouTube Trending Video Views'] = topTrendingVideoManual_1[3]	
#     df_master_dataset.at[i, 'YouTube Trending Video Likes'] = topTrendingVideoManual_1[4]

# topTrendingVideoManual_2 = ['BAD BUNNY x ROSAL√çA - LA NOCHE DE ANOCHE (Video Official)', 'Bad Bunny', 'Music', 46388874, 1381354]

# for i in range():
#     df_master_dataset.at[i, 'YouTube Trending Video Title'] = topTrendingVideoManual_1[0]
#     df_master_dataset.at[i, 'YouTube Trending Video Channel'] = topTrendingVideoManual_1[1]	
#     df_master_dataset.at[i, 'YouTube Trending Video Category'] = topTrendingVideoManual_1[2]
#     df_master_dataset.at[i, 'YouTube Trending Video Views'] = topTrendingVideoManual_1[3]	
#     df_master_dataset.at[i, 'YouTube Trending Video Likes'] = topTrendingVideoManual_1[4]

# topTrendingVideoManual_3 = ['Steal This $100,000 Diamond, You Keep It', 'MrBeast', 'Entertainment', 25165862, 1204609]

# for i in range(1498, 1502, 1):
#     df_master_dataset.at[i, 'YouTube Trending Video Title'] = topTrendingVideoManual_3[0]
#     df_master_dataset.at[i, 'YouTube Trending Video Channel'] = topTrendingVideoManual_3[1]	
#     df_master_dataset.at[i, 'YouTube Trending Video Category'] = topTrendingVideoManual_3[2]
#     df_master_dataset.at[i, 'YouTube Trending Video Views'] = topTrendingVideoManual_3[3]	
#     df_master_dataset.at[i, 'YouTube Trending Video Likes'] = topTrendingVideoManual_3[4]

# %%
df_master_dataset.head(25)
# Out:
#     Story Primary ID       Story ID  User Primary ID        User ID  Gender  \
# 0             121169  STY1659426957              103  USR1606807023  female
# 1             127727  STY1660634861              103  USR1606807023  female
# 2             123665  STY1660027898              103  USR1606807023  female
# 3             130517  STY1661151635              103  USR1606807023  female
# 4             125466  STY1660372361              109  USR1606851217  others
# 5             129472  STY1660912862                2  USR1605614195  others
# 6             128902  STY1660827749                2  USR1605614195  others
# 7             124381  STY1660146053                2  USR1605614195  others
# 8             121828  STY1659554880                2  USR1605614195  others
# 9             121349  STY1659450917                2  USR1605614195  others
# 10            121347  STY1659450529                2  USR1605614195  others
# 11            101194  STY1652952597                2  USR1605614195  others
# 12             97563  STY1651295583                2  USR1605614195  others
# 13            128902  STY1660827749                2  USR1605614195  others
# 14            140715  STY1662783489                2  USR1605614195  others
# 15            140437  STY1662714298                2  USR1605614195  others
# 16            101202  STY1652953935                2  USR1605614195  others
# 17            156042  STY1665941854                2  USR1605614195  others
# 18            140774  STY1662801172                2  USR1605614195  others
# 19             99819  STY1652353115                2  USR1605614195  others
# 20            135323  STY1661921594                2  USR1605614195  others
# 21             95270  STY1650446022                2  USR1605614195  others
# 22            101470  STY1653062254                2  USR1605614195  others
# 23            129472  STY1660912862                2  USR1605614195  others
# 24            102248  STY1653383665                2  USR1605614195  others
#
#     Age                                              Title  \
# 0    34                      Trend of the Year: Barbiecore
# 1    34                             Abomination of the day
# 2    34                          Shameful headline in 2022
# 3    34   Woman lawyer arrested for abusing security guard
# 4    31               What is the Inflation Reduction Act?
# 5    27                       August is my favourite month
# 6    27                        How bad are things at ManU?
# 7    27  Trump raided by FBI in Florida, pleads Fifth A...
# 8    27                                       Hi, whats up
# 9    27                You can never go wrong with Led Zep
# 10   27                       What's on your reading list?
# 11   27            Prices are really getting out of hand 😑
# 12   27                   News about LBJ retiring is false
# 13   27                        How bad are things at ManU?
# 14   27                    Carlos Alcaraz is the real deal
# 15   27  https://www.pixstory.com/story/al-bidda-park-t...
# 16   27                    Tom Cruise is an ageless wonder
# 17   27        Arsenal at the top with a big 4 points lead
# 18   27  MS Dhoni in the stands watching Carlos Alcaraz...
# 19   27                   Why is China so scared of Covid?
# 20   27                           The Serena Williams show
# 21   27                  No one's watching Netflix anymore
# 22   27            Can Carlos Alcaraz be tennis's saviour?
# 23   27                       August is my favourite month
# 24   27                                        Storm tales
#
#                                             Narrative  \
# 0   The colour of the year is here, and it's *drum...
# 1   We Indians do love to bastardise our foods- Ch...
# 2   Can professors not have personal lives? \n\nAd...
# 3   She was recorded on video manhandling him, sho...
# 4   The House passed the Inflation Reduction Act o...
# 5   <p dir="ltr"><a href="https://www.google.com">...
# 6   <p dir="ltr">How bad are things at ManU?</p>\n...
# 7   <p dir="ltr">The noose is tightening.</p>\n<p ...
# 8                       <p dir="ltr">Hi, whats up</p>
# 9   <p dir="ltr">You can never go wrong with <b>Le...
# 10  <p dir="ltr">Whatss on your <i>reading</i> lis...
# 11                 Prices are extortionary these days
# 12  "I will not miss the post season again for my ...
# 13  <p dir="ltr">How bad are things at ManU?</p>\n...
# 14  <p dir="ltr">Carlos Alcaraz is on the cusp of ...
# 15  <p dir="ltr">https://www.pixstory.com/story/al...
# 16  Cant wait for Top Gun Maverick. First movie I'...
# 17  <p dir="ltr">What a match! </p>\n<p dir="ltr">...
# 18  <p dir="ltr">&#127470;&#127475;&#127951; legen...
# 19  While the world has largely reopened after two...
# 20  <p dir="ltr">Defending champ Emma Raducanu kno...
# 21  Netflix has revealed that it lost 200,000 subs...
# 22  <p dir="ltr">Tennis is staring at a crisis. </...
# 23  <p dir="ltr"><a href="https://www.google.com">...
# 24  Yesterday's storm left a trail of destruction ...
#
#                                                 Media Account Created Date  \
# 0   https://image.pixstory.com/Pixstory-image-1659...  2020-01-12 12:47:00
# 1   https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 2   https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 3   https://image.pixstory.com/Pixstory-image-1661...  2020-01-12 12:47:00
# 4   https://image.pixstory.com/Pixstory-image-1660...  2020-02-12 01:03:00
# 5   https://image.pixstory.com/Pixstory-image-1647...  2020-11-17 17:26:00
# 6   https://image.pixstory.com/Pixstory-image-1634...  2020-11-17 17:26:00
# 7   https://image.pixstory.com/Pixstory-image-1660...  2020-11-17 17:26:00
# 8   https://image.pixstory.com/Pixstory-image-1659...  2020-11-17 17:26:00
# 9   https://image.pixstory.com/Pixstory-image-1659...  2020-11-17 17:26:00
# 10  https://image.pixstory.com/Pixstory-image-1659...  2020-11-17 17:26:00
# 11  https://image.pixstory.com/Pixstory-image-1652...  2020-11-17 17:26:35
# 12  https://image.pixstory.com/Pixstory-image-1651...  2020-11-17 17:26:35
# 13  https://image.pixstory.com/Pixstory-image-1634...  2020-11-17 17:26:35
# 14  https://image.pixstory.com/Pixstory-image-1653...  2020-11-17 17:26:35
# 15  https://image.pixstory.com/Pixstory-image-1660...  2020-11-17 17:26:35
# 16  https://image.pixstory.com/Pixstory-image-1652...  2020-11-17 17:26:35
# 17  https://image.pixstory.com/Pixstory-image-1665...  2020-11-17 17:26:35
# 18  https://image.pixstory.com/Pixstory-image-1662...  2020-11-17 17:26:35
# 19  https://image.pixstory.com/Pixstory-image-1652...  2020-11-17 17:26:35
# 20  https://image.pixstory.com/Pixstory-image-1661...  2020-11-17 17:26:35
# 21  https://image.pixstory.com/Pixstory-image-1650...  2020-11-17 17:26:35
# 22  https://image.pixstory.com/Pixstory-image-1653...  2020-11-17 17:26:35
# 23  https://image.pixstory.com/Pixstory-image-1647...  2020-11-17 17:26:35
# 24  https://image.pixstory.com/Pixstory-image-1621...  2020-11-17 17:26:35
#
#    Date (No Timestamp)                                           Interest  \
# 0           2020-01-12                            trends, fashion, barbie
# 1           2020-01-12                           Food, momos, weird menus
# 2           2020-01-12                              misogyny, st  xaviers
# 3           2020-01-12  Technology, History, Food, Entertainment, Spor...
# 4           2020-02-12                                      us government
# 5           2020-11-17  Technology, History, Food, Entertainment, Spor...
# 6           2020-11-17  Technology, History, Food, Entertainment, Spor...
# 7           2020-11-17  Technology, History, Food, Entertainment, Spor...
# 8           2020-11-17  Technology, History, Food, Entertainment, Spor...
# 9           2020-11-17  Technology, History, Food, Entertainment, Spor...
# 10          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 11          2020-11-17                                          inflation
# 12          2020-11-17                            basketball, Sports, nba
# 13          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 14          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 15          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 16          2020-11-17                                            top gun
# 17          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 18          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 19          2020-11-17                                 china, coronavirus
# 20          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 21          2020-11-17                                            netflix
# 22          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 23          2020-11-17  Technology, History, Food, Entertainment, Spor...
# 24          2020-11-17                                            testing
#
#                          YouTube Trending Video Title  \
# 0                                      I'm Coming Out
# 1                                      I'm Coming Out
# 2                                      I'm Coming Out
# 3                                      I'm Coming Out
# 4                                      I'm Coming Out
# 5   Billie Eilish - Therefore I Am (Official Music...
# 6   Billie Eilish - Therefore I Am (Official Music...
# 7   Billie Eilish - Therefore I Am (Official Music...
# 8   Billie Eilish - Therefore I Am (Official Music...
# 9   Billie Eilish - Therefore I Am (Official Music...
# 10  Billie Eilish - Therefore I Am (Official Music...
# 11  Billie Eilish - Therefore I Am (Official Music...
# 12  Billie Eilish - Therefore I Am (Official Music...
# 13  Billie Eilish - Therefore I Am (Official Music...
# 14  Billie Eilish - Therefore I Am (Official Music...
# 15  Billie Eilish - Therefore I Am (Official Music...
# 16  Billie Eilish - Therefore I Am (Official Music...
# 17  Billie Eilish - Therefore I Am (Official Music...
# 18  Billie Eilish - Therefore I Am (Official Music...
# 19  Billie Eilish - Therefore I Am (Official Music...
# 20  Billie Eilish - Therefore I Am (Official Music...
# 21  Billie Eilish - Therefore I Am (Official Music...
# 22  Billie Eilish - Therefore I Am (Official Music...
# 23  Billie Eilish - Therefore I Am (Official Music...
# 24  Billie Eilish - Therefore I Am (Official Music...
#
#    YouTube Trending Video Channel YouTube Trending Video Category  \
# 0                  NikkeTutorials                         Fashion
# 1                  NikkeTutorials                         Fashion
# 2                  NikkeTutorials                         Fashion
# 3                  NikkeTutorials                         Fashion
# 4                  NikkeTutorials                         Fashion
# 5                BillieEilishVEVO                           Music
# 6                BillieEilishVEVO                           Music
# 7                BillieEilishVEVO                           Music
# 8                BillieEilishVEVO                           Music
# 9                BillieEilishVEVO                           Music
# 10               BillieEilishVEVO                           Music
# 11               BillieEilishVEVO                           Music
# 12               BillieEilishVEVO                           Music
# 13               BillieEilishVEVO                           Music
# 14               BillieEilishVEVO                           Music
# 15               BillieEilishVEVO                           Music
# 16               BillieEilishVEVO                           Music
# 17               BillieEilishVEVO                           Music
# 18               BillieEilishVEVO                           Music
# 19               BillieEilishVEVO                           Music
# 20               BillieEilishVEVO                           Music
# 21               BillieEilishVEVO                           Music
# 22               BillieEilishVEVO                           Music
# 23               BillieEilishVEVO                           Music
# 24               BillieEilishVEVO                           Music
#
#     YouTube Trending Video Views  YouTube Trending Video Likes
# 0                     36400000.0                     3000000.0
# 1                     36400000.0                     3000000.0
# 2                     36400000.0                     3000000.0
# 3                     36400000.0                     3000000.0
# 4                     36400000.0                     3000000.0
# 5                     32911660.0                     3024635.0
# 6                     32911660.0                     3024635.0
# 7                     32911660.0                     3024635.0
# 8                     32911660.0                     3024635.0
# 9                     32911660.0                     3024635.0
# 10                    32911660.0                     3024635.0
# 11                    32911660.0                     3024635.0
# 12                    32911660.0                     3024635.0
# 13                    32911660.0                     3024635.0
# 14                    32911660.0                     3024635.0
# 15                    32911660.0                     3024635.0
# 16                    32911660.0                     3024635.0
# 17                    32911660.0                     3024635.0
# 18                    32911660.0                     3024635.0
# 19                    32911660.0                     3024635.0
# 20                    32911660.0                     3024635.0
# 21                    32911660.0                     3024635.0
# 22                    32911660.0                     3024635.0
# 23                    32911660.0                     3024635.0
# 24                    32911660.0                     3024635.0

# %%
df_master_dataset.to_csv('../Master Datasets/Master_Dataset_Merged_NoSarcasm.csv', index=True)
