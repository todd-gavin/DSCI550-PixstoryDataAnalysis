# %% [markdown]
# # `Hate Speech Flag feature`

# %%
import requests
import urllib.request, urllib.parse, urllib.error
import re
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# Using the requests library, we will perform an API call for every webpage that contians hate speech symbols to collect.

# %%
def API_call_hate_speech(url):

    hate_speech_list = []

    # Make a request to the web page
    html = urllib.request.urlopen(url).read()

    # Parse the HTML content of the page
    soup = BeautifulSoup(html, 'html.parser')

    # Find all div blocks that have the class "global-search__row"
    hate_speech = soup.find_all('span', {'class': 'field field--name-title field--type-string field--label-hidden'})

    hate_speech = list(hate_speech)

    for speech in hate_speech:
        hate_speech_list.append(speech.text)


    return hate_speech_list

# %%
# Loop through each webpage, and call API, append hate speech smybols to list
hateSpeechList = []

for i in range(11):

    url = 'https://www.adl.org/resources/hate-symbols/search?keywords=&sort_by=title&page=' + str(i)
    # print("***** Page:", i+1)
    hateSpeechList = hateSpeechList + API_call_hate_speech(url)

# %% [markdown]
# Now that we have a list of hate speech symbol, we need to clean the list, making sure to remove duplicates and clean up errors

# %%
for i in range(len(hateSpeechList)):

    if i == 5:
        hateSpeechList[i] = "13/52"
        hateSpeechList.append("13/90")
    elif i == 14: 
        hateSpeechList[i] = "23"
    elif i == 26: 
        hateSpeechList[i] = "88"
    elif i == 33: 
        hateSpeechList[i] = "American Identity Movement"
        hateSpeechList.append("AIM")
    elif i == 41 or i == 48 or i == 49 or i == 80 or i == 146 or i == 177 or i == 197 or i == 200: 
        hateSpeechList.pop(i)
    elif i == 62: 
        hateSpeechList[i] = "Bowlcut"
        hateSpeechList.append("Dylann Roof")
    elif i == 92: 
        hateSpeechList[i] = "hammerskin"
    elif i == 98: 
        hateSpeechList[i] = "Hitler salute"
    elif i == 113: 
        hateSpeechList[i] = "Ku Klux Klan"
    elif i == 156: 
        hateSpeechList[i] = "Runic Writing"
    elif i == 168: 
        hateSpeechList[i] = "South African Flag"
        hateSpeechList.append("Apartheid Era")
    elif i == 172: 
        hateSpeechList[i] = "SS"
    elif i == 180: 
        hateSpeechList[i] = "The Goyim Know"
        hateSpeechList.append("Shut It Down")
    elif i == 188: 
        hateSpeechList[i] = "Trollface"
    elif i == 201: 
        hateSpeechList[i] = "WAR"
        hateSpeechList.append("Arkansas prison gang")
    elif i == 206: 
        hateSpeechList[i] = "white power"

# %% [markdown]
# # Extracting Narrative from Pixstory raw Dataset using Beauitful Soup

# %%
df_master_dataset = pd.read_csv("../Master Datasets/Master_Dataset_Raw_FilmFestivals.csv")

# %%
# a function to extract the text from an HTML string
# def extract_text(html):
#     try: 
#         soup = BeautifulSoup(html, 'html.parser')
#         text = soup.get_text()
#     except:
#         text = html

#     return text

# # Apply the function to each row of the DataFrame and create a new column with the result
# df_master_dataset['Narrative'] = df_master_dataset['Narrative'].apply(extract_text)

# %%
df_master_dataset.tail(20)
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID Gender  \
# 94980            125309  STY1660320951            71571  USR1660320087    NaN
# 94981            125310  STY1660321036            71571  USR1660320087    NaN
# 94982            125311  STY1660321093            71571  USR1660320087    NaN
https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 23:14:00
#
#       Date (No Timestamp)                          Interest  \
# 94980          2022-12-08                              qotd
# 94981          2022-12-08                               bts
# 94982          2022-12-08                               bts
# 94983          2022-12-08                       collegelife
# 94984          2022-12-08                college life umang
# 94985          2022-12-08                      college fest
# 94986          2022-12-08                      college life
# 94987          2022-12-08                      college life
# 94988          2022-12-08                      college life
# 94989          2022-12-08  college life, college life umang
# 94990          2022-12-08                      college life
# 94991          2022-12-08                      college life
# 94992          2022-12-08                      college life
# 94993          2022-12-08                      college life
# 94994          2022-12-08                      college life
# 94995          2022-12-08  college life, college life umang
# 94996          2022-12-08                      college life
# 94997          2022-12-08  college life, college life umang
# 94998          2022-12-08                           friends
# 94999          2022-12-08                      college life
#
#                              Sports Events Associated Film Festivals
# 94980  FIFA World Cup, World Championships                       NaN
# 94981  FIFA World Cup, World Championships                       NaN
# 94982  FIFA World Cup, World Championships                       NaN
# 94983  FIFA World Cup, World Championships                       NaN
# 94984  FIFA World Cup, World Championships                       NaN
# 94985  FIFA World Cup, World Championships                       NaN
# 94986  FIFA World Cup, World Championships                       NaN
# 94987  FIFA World Cup, World Championships                       NaN
# 94988  FIFA World Cup, World Championships                       NaN
# 94989  FIFA World Cup, World Championships                       NaN
# 94990  FIFA World Cup, World Championships                       NaN
# 94991  FIFA World Cup, World Championships                       NaN
# 94992  FIFA World Cup, World Championships                       NaN
# 94993  FIFA World Cup, World Championships                       NaN
# 94994  FIFA World Cup, World Championships                       NaN
# 94995  FIFA World Cup, World Championships                       NaN
# 94996  FIFA World Cup, World Championships                       NaN
# 94997  FIFA World Cup, World Championships                       NaN
# 94998  FIFA World Cup, World Championships                       NaN
# 94999  FIFA World Cup, World Championships                       NaN

# %% [markdown]
# # Classify Hate Speech based on Pixstory Narrative

# %%
df_master_dataset['Narrative'] = df_master_dataset['Narrative'].astype(str)

# %%
df_master_dataset['Hate Speech Flag'] = ""
df_master_dataset['Hate Speech Detected'] = ""

# %%
# This function gets the title and narrative from the pixstory dataset and checks if it contians symbols that are found in the hateSpeech List

# 1 indicated hate speech detected
# 0 indicates no hate speech detected

def classify_text(title, narrative, hateSpeechList):

    for word in hateSpeechList:
        if word in title or word in narrative:
            return '1', word
        else:
            return '0', 'N/A'

# %%
# Loop through every row in the picstory dataset and apply the classify text function
for index, row in df_master_dataset.iterrows():
    narrative = row["Narrative"]
    title = row["Title"]
    classification, word = classify_text(title, narrative, hateSpeechList)
    df_master_dataset.loc[index, "Hate Speech Flag"] = classification
    df_master_dataset.loc[index, "Hate Speech Detected"] = word

# %%
df_master_dataset
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 0                121169  STY1659426957              103  USR1606807023
# 1                127727  STY1660634861              103  USR1606807023
# 2                123665  STY1660027898              103  USR1606807023
# 3                130517  STY1661151635              103  USR1606807023
# 4                125466  STY1660372361              109  USR1606851217
# ...                 ...            ...              ...            ...
# 94995            125349  STY1660325841            71665  USR1660325291
# 94996            125345  STY1660325638            71673  USR1660325486
# 94997            125355  STY1660326971            71697  USR1660326022
# 94998            125351  STY1660326276            71698  USR1660326026
# 94999            125354  STY1660326403            71708  USR1660326251
#
#        Gender  Age                                             Title  \
# 0      female   34                     Trend of the Year: Barbiecore
# 1      female   34                            Abomination of the day
# 2      female   34                         Shameful headline in 2022
# 3      female   34  Woman lawyer arrested for abusing security guard
# 4      others   31              What is the Inflation Reduction Act?
# ...       ...  ...                                               ...
# 94995     NaN   18                                      COLLEGE LIFE
# 94996     NaN   17                          The one with the bestie😍
# 94997     NaN   19                                           College
# 94998     NaN   21                              A tale of friendship
# 94999     NaN   17                       The mandatory mirror selfie
#
#                                                Narrative  \
# 0      The colour of the year is here, and it's *drum...
# 1      We Indians do love to bastardise our foods- Ch...
# 2      Can professors not have personal lives? \n\nAd...
# 3      She was recorded on video manhandling him, sho...
# 4      The House passed the Inflation Reduction Act o...
# ...                                                  ...
# 94995                                         MODR CLASS
# 94996  College life without a friend is useless. Enjo...
# 94997            Sheridan college, HazelMcCallion Canpus
# 94998                                    Check this out.
# 94999  Spending time in college with these two maddie...
#
#                                                    Media Account Created Date  \
# 0      https://image.pixstory.com/Pixstory-image-1659...  2020-01-12 12:47:00
# 1      https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 2      https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 3      https://image.pixstory.com/Pixstory-image-1661...  2020-01-12 12:47:00
# 4      https://image.pixstory.com/Pixstory-image-1660...  2020-02-12 01:03:00
# ...                                                  ...                  ...
# 94995  https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 22:58:00
# 94996  https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 23:01:00
# 94997  https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 23:10:00
# 94998  https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 23:10:00
# 94999  https://image.pixstory.com/Pixstory-image-1660...  2022-12-08 23:14:00
#
#       Date (No Timestamp)                                           Interest  \
# 0              2020-01-12                            trends, fashion, barbie
# 1              2020-01-12                           Food, momos, weird menus
# 2              2020-01-12                              misogyny, st  xaviers
# 3              2020-01-12  Technology, History, Food, Entertainment, Spor...
# 4              2020-02-12                                      us government
# ...                   ...                                                ...
# 94995          2022-12-08                   college life, college life umang
# 94996          2022-12-08                                       college life
# 94997          2022-12-08                   college life, college life umang
# 94998          2022-12-08                                            friends
# 94999          2022-12-08                                       college life
#
#                              Sports Events  \
# 0                    Winter Youth Olympics
# 1                    Winter Youth Olympics
# 2                    Winter Youth Olympics
# 3                    Winter Youth Olympics
# 4                              Six Nations
# ...                                    ...
# 94995  FIFA World Cup, World Championships
# 94996  FIFA World Cup, World Championships
# 94997  FIFA World Cup, World Championships
# 94998  FIFA World Cup, World Championships
# 94999  FIFA World Cup, World Championships
#
#                                Associated Film Festivals Hate Speech Flag  \
# 0      Palm Springs International Film Festival, Miam...                0
# 1      Palm Springs International Film Festival, Miam...                0
# 2      Palm Springs International Film Festival, Miam...                0
# 3      Palm Springs International Film Festival, Miam...                0
# 4      New Jersey International Film Festival, Palm B...                0
# ...                                                  ...              ...
# 94995                                                NaN                0
# 94996                                                NaN                0
# 94997                                                NaN                0
# 94998                                                NaN                0
# 94999                                                NaN                0
#
#       Hate Speech Detected
# 0                      N/A
# 1                      N/A
# 2                      N/A
# 3                      N/A
# 4                      N/A
# ...                    ...
# 94995                  N/A
# 94996                  N/A
# 94997                  N/A
# 94998                  N/A
# 94999                  N/A
#
# [95000 rows x 16 columns]

# %%
df_master_dataset.to_csv('../Master Datasets/Master_Dataset_Raw_HateSpeech.csv', index=False)
